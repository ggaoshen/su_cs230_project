# %%
from environment import Market, get_ts
from model import Q_Model
from agent import Agent
from simulator import Simulator
import pandas as pd
import matplotlib.pyplot as plt

# sampler = Single_Signal_Generator(total_timesteps=180, period_range=(10, 40), amplitude_range=(5, 80), noise_amplitude_ratio=0.5)
# filename = "Generated Signals.npy"
# sampler.build_signals(filename, 1000)
# sampler.load(filename)
# env = Market(sampler=sampler, last_n_timesteps=40, trans_cost=3.3)

# ticker=['MS']
# ticker=['TSLA']
# ticker=['TSLA', 'GOOGL', 'MS', 'KO', 'CVX', 'HD', 'MMM' ,'BA']
# sample = get_ts(ticker)
# sample.to_csv('data/test/test_data_8stockmix.csv')
sample = pd.read_csv('data/test/test_data_8stockmix.csv', index_col=0)
# sample = pd.read_csv('data/test/test_data.csv', index_col=0)
print(sample.head())
# print(sample.shape)
# print(sample.dtypes)
env_train = Market(sample.iloc[:1500, :], 20, 0.5)
env_test = Market(sample.iloc[1500:, :], 20, 0.5)
# env.reset()

dense_model = [
    {"type":"Reshape", "target_shape":(env_train.get_state().shape[0]*env_train.get_state().shape[1],)},
    {"type":"Dense", "units":64*env_train.get_state().shape[1]},
    {"type":"Dense", "units":64}
]
conv_model = [
    {"type":"Reshape", "target_shape":env_train.get_state().shape},
    {"type":"Conv1D", "filters":16, "kernel_size":3, "activation":"relu"},
    {"type":"Conv1D", "filters":16, "kernel_size":3, "activation":"relu"},
    {"type":"Flatten"},
    {"type":"Dense", "units":48, "activation":"relu"},
    {"type":"Dense", "units":24, "activation":"relu"}
]
gru_model = [
    {"type":"Reshape", "target_shape":env_train.get_state().shape},
    {"type":"GRU", "units":16, "return_sequences":True},
    {"type":"GRU", "units":16, "return_sequences":False},
    {"type":"Dense", "units":16, "activation":"relu"},
    # {"type":"Dense", "units":16, "activation":"relu"}
]
lstm_model = [
    {"type":"Reshape", "target_shape":env_train.get_state().shape},
    {"type":"LSTM", "units":16, "return_sequences":True},
    {"type":"LSTM", "units":16, "return_sequences":False},
    {"type":"Dense", "units":16, "activation":"relu"},
    # {"type":"Dense", "units":16, "activation":"relu"}
]

q_model = Q_Model("Dense_8stocks", state_dim=env_train.get_state().shape, no_of_actions=env_train.no_of_actions, layers=dense_model, hyperparameters={"lr":0.0001})
agent = Agent(q_model, batch_size=8, discount_factor=0.995, epsilon=1)

no_epochs = 300

sim = Simulator(env_train, agent)
ep_end_portf_val_train, last_eps_position_ts_train, exploration_episode_rewards_train = sim.train(no_epochs, epsilon_decay=0.995)
print(ep_end_portf_val_train)

# agent.model.save() 

sim_test = Simulator(env_test, agent)
test_portf_val_ts, test_position_ts, test_ending_rewards = sim_test.test()
# print(test_portf_val_ts)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#              TSLA     GOOGL       MS      IBM       KO      CVX       HD  \
# date
# 2010-06-29  23.89  227.8333  20.1909  94.0708  18.8046  47.9884  22.9363
# 2010-06-30  23.83  223.1639  19.9843  92.8600  18.7262  47.6374  22.4877
# 2010-07-01  21.96  220.4254  19.8809  92.1757  18.6925  47.3706  22.3675
# 2010-07-02  19.20  218.9509  19.6571  91.6417  18.7000  47.2513  22.2393
# 2010-07-06  16.11  218.7101  19.7776  92.8450  18.8420  47.4268  21.9029
#
#                 MCD
# date
# 2010-06-29  50.1788
# 2010-06-30  49.7334
# 2010-07-01  50.3676
# 2010-07-02  49.9372
# 2010-07-06  49.9146
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          (None, 160)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               82432
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                16416
# _________________________________________________________________
# dense_9 (Dense)              (None, 40)                1320
# =================================================================
# Total params: 100,168
# Trainable params: 100,168
# Non-trainable params: 0
# _________________________________________________________________
# ------------------------------------------------------------
# Training
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-08751f595e0a> in <module>
#      62
#      63 sim = Simulator(env_train, agent)
# ---> 64 train_rewards = sim.train(no_epochs, epsilon_decay=0.997)
#      65 agent.model.save()
#      66
#
# ~/Documents/GitHub/su_cs230_project/simulator.py in train(self, num_epochs, epsilon_decay, min_epsilon, epsilon, progress_report)
#      49             # exploration_episode_rewards.append(exploration_episode_reward)
#      50             # exploration_max_episode_rewards.append(exploration_max_episode_reward)
# ---> 51             exploration_episode_reward = self.play_one_episode(epsilon, training=True)
#      52             exploration_episode_rewards.append(exploration_episode_reward)
#      53
#
# ~/Documents/GitHub/su_cs230_project/simulator.py in play_one_episode(self, epsilon, training)
#      19         while not done:
#      20
# ---> 21             action = self.agent.act(state, self.env.valid_actions)
#      22             next_state, reward, done = self.env.step(action)
#      23
#
# ~/Documents/GitHub/su_cs230_project/agent.py in act(self, state, valid_actions)
#      23             # if np.nanmin(q_valid) != np.nanmax(q_valid):
#      24             return np.nanargmax(q_valid, axis=0)
# ---> 25         return np.array(random.sample(list(valid_actions), state.shape[1]))
#      26
#      27     def remember(self, experience):
#
# /opt/anaconda3/lib/python3.7/random.py in sample(self, population, k)
#     319         n = len(population)
#     320         if not 0 <= k <= n:
# --> 321             raise ValueError("Sample larger than population or is negative")
#     322         result = [None] * k
#     323         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
import matplotlib.pyplot as plt
plt.plot(env_train.portfolio_value)

# %%
plt.plot(env_train.sample_2d)
# Out:
# [<matplotlib.lines.Line2D at 0x642881550>,
#  <matplotlib.lines.Line2D at 0x6428813d0>]

# %%
import numpy as np 
plt.plot(env_train.positions)
# Out:
# [<matplotlib.lines.Line2D at 0x6473ee110>,
#  <matplotlib.lines.Line2D at 0x6473ee390>]

# %%
plt.plot(np.sum(train_rewards,axis=1))

# %%
plt.plot(env_test.portfolio_value)

# %%
plt.plot(env_test.sample_2d)
# Out:
# [<matplotlib.lines.Line2D at 0x646ca06d0>,
#  <matplotlib.lines.Line2D at 0x646ca08d0>]

# %%
plt.plot(env_test.positions)
# Out:
# [<matplotlib.lines.Line2D at 0x6470a0ed0>,
#  <matplotlib.lines.Line2D at 0x6470ac190>]

# %%
test_rewards
# Out:
# [array([-107273.59268731,  129206.32935356])]

# %%
plt.plot(np.sum(train_rewards,axis=1))

# %%
env_train.sample_2d
# Out:
# array([[ 31.8384,  23.89  ],
#        [ 31.2617,  23.83  ],
#        [ 30.8827,  21.96  ],
#        ...,
#        [ 94.1832, 229.36  ],
#        [ 93.4082, 218.79  ],
#        [ 91.9999, 217.87  ]])

# %%
env_train.tickers
# Out:
# Index(['AAPL', 'TSLA'], dtype='object')

# %%
import random
import numpy as np
# random.sample(np.arange(5), 8)
list1 = [1, 2, 3, 4, 5]  
  
print(random.sample(list1,9))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9a28b8accf19> in <module>
#       4 list1 = [1, 2, 3, 4, 5]
#       5
# ----> 6 print(random.sample(list1,9))
#
# /opt/anaconda3/lib/python3.7/random.py in sample(self, population, k)
#     319         n = len(population)
#     320         if not 0 <= k <= n:
# --> 321             raise ValueError("Sample larger than population or is negative")
#     322         result = [None] * k
#     323         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
np.array([random.choice(list1) for _ in range(9)])
# Out:
# array([1, 1, 5, 2, 4, 4, 3, 3, 2])

# %%
sample.ewm(com=9.5).mean().head(60).plot()
sample.head(60).plot()
